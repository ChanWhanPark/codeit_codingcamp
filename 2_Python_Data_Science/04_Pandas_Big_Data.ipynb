# %%
import pandas as pd

# %%
laptops_df = pd.read_csv('laptops.csv')

# %%
laptops_df
# Out:
#      brand             model  ram hd_type  hd_size  screen_size   price  \
# 0     Dell  Inspiron 15-3567    4     hdd     1024         15.6   40000
# 1    Apple       MacBook Air    8     ssd      128         13.3   55499
# 2    Apple       MacBook Air    8     ssd      256         13.3   71500
# 3    Apple       MacBook Pro    8     ssd      128         13.3   96890
# 4    Apple       MacBook Pro    8     ssd      256         13.3  112666
# ..     ...               ...  ...     ...      ...          ...     ...
# 162   Asus            A555LF    8     hdd     1024         15.6   39961
# 163   Asus     X555LA-XX172D    4     hdd      500         15.6   28489
# 164   Asus            X554LD    2     hdd      500         15.6   29199
# 165   Asus    X550LAV-XX771D    2     hdd      500         15.6   29990
# 166   Asus     X540LA-XX538T    4     hdd     1024         15.6   30899
#
#     processor_brand processor_model  clock_speed graphic_card_brand  \
# 0             intel              i5          2.5              intel
# 1             intel              i5          1.8              intel
# 2             intel              i5          1.8              intel
# 3             intel              i5          2.3              intel
# 4             intel              i5          2.3              intel
# ..              ...             ...          ...                ...
# 162           intel      i3 4th gen          1.7             nvidia
# 163           intel      i3 4th gen          1.9              intel
# 164           intel      i3 4th gen          1.9              intel
# 165           intel      i3 4th gen          1.7              intel
# 166           intel      i3 5th gen          2.0              intel
#
#      graphic_card_size       os  weight comments
# 0                  NaN    linux    2.50      NaN
# 1                  2.0      mac    1.35      NaN
# 2                  2.0      mac    1.35      NaN
# 3                  2.0      mac    3.02      NaN
# 4                  2.0      mac    3.02      NaN
# ..                 ...      ...     ...      ...
# 162                2.0  windows    2.30      NaN
# 163                NaN    linux    2.30      NaN
# 164                1.0    linux    2.30      NaN
# 165                NaN    linux    2.50      NaN
# 166                NaN  windows    2.30      NaN
#
# [167 rows x 15 columns]

# %%
laptops_df.tail(6)
# Out:
#     brand           model  ram hd_type  hd_size  screen_size  price  \
# 161  Asus  X541UA-GO1345D    4     hdd     1024         15.6  27730
# 162  Asus          A555LF    8     hdd     1024         15.6  39961
# 163  Asus   X555LA-XX172D    4     hdd      500         15.6  28489
# 164  Asus          X554LD    2     hdd      500         15.6  29199
# 165  Asus  X550LAV-XX771D    2     hdd      500         15.6  29990
# 166  Asus   X540LA-XX538T    4     hdd     1024         15.6  30899
#
#     processor_brand processor_model  clock_speed graphic_card_brand  \
# 161           intel      i3 6th gen          2.0              intel
# 162           intel      i3 4th gen          1.7             nvidia
# 163           intel      i3 4th gen          1.9              intel
# 164           intel      i3 4th gen          1.9              intel
# 165           intel      i3 4th gen          1.7              intel
# 166           intel      i3 5th gen          2.0              intel
#
#      graphic_card_size       os  weight comments
# 161                NaN    linux    1.84      NaN
# 162                2.0  windows    2.30      NaN
# 163                NaN    linux    2.30      NaN
# 164                1.0    linux    2.30      NaN
# 165                NaN    linux    2.50      NaN
# 166                NaN  windows    2.30      NaN

# %%
laptops_df.shape
# Out:
# (167, 15)

# %%
laptops_df.columns
# Out:
# Index(['brand', 'model', 'ram', 'hd_type', 'hd_size', 'screen_size', 'price',
#        'processor_brand', 'processor_model', 'clock_speed',
#        'graphic_card_brand', 'graphic_card_size', 'os', 'weight', 'comments'],
#       dtype='object')

# %%
laptops_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   brand               167 non-null    object
#  1   model               167 non-null    object
#  2   ram                 167 non-null    int64
#  3   hd_type             167 non-null    object
#  4   hd_size             167 non-null    int64
#  5   screen_size         167 non-null    float64
#  6   price               167 non-null    int64
#  7   processor_brand     167 non-null    object
#  8   processor_model     167 non-null    object
#  9   clock_speed         166 non-null    float64
#  10  graphic_card_brand  163 non-null    object
#  11  graphic_card_size   81 non-null     float64
#  12  os                  167 non-null    object
#  13  weight              160 non-null    float64
#  14  comments            55 non-null     object
# dtypes: float64(4), int64(3), object(8)
# memory usage: 19.7+ KB

# %%
laptops_df.describe()
# Out:
#               ram     hd_size  screen_size          price  clock_speed  \
# count  167.000000   167.00000   167.000000     167.000000   166.000000
# mean     6.898204   768.91018    14.775210   64132.898204     2.321084
# std      3.787479   392.99080     1.376526   42797.674010     0.554187
# min      2.000000    32.00000    10.100000   13872.000000     1.100000
# 25%      4.000000   500.00000    14.000000   35457.500000     1.900000
# 50%      8.000000  1024.00000    15.600000   47990.000000     2.300000
# 75%      8.000000  1024.00000    15.600000   77494.500000     2.600000
# max     16.000000  2048.00000    17.600000  226000.000000     3.800000
#
#        graphic_card_size      weight
# count          81.000000  160.000000
# mean           52.160494    2.250812
# std           444.134142    0.648446
# min             1.000000    0.780000
# 25%             2.000000    1.900000
# 50%             2.000000    2.200000
# 75%             4.000000    2.600000
# max          4000.000000    4.200000

# %%
laptops_df.sort_values(by='price')
# Out:
#          brand                       model  ram hd_type  hd_size  screen_size  \
# 148       Acer             Aspire SW3-016     2     ssd       32         10.1
# 83        Acer     A315-31CDC UN.GNTSI.001    2     ssd      500         15.6
# 108       Acer  Aspire ES-15 NX.GKYSI.010     4     hdd      500         15.6
# 100       Acer    A315-31-P4CRUN.GNTSI.002    4     hdd      500         15.6
# 73        Acer             Aspire ES1-523     4     hdd     1024         15.6
# ..         ...                         ...  ...     ...      ...          ...
# 154  Microsoft      Surface Book CR9-00013    8     ssd      128         13.5
# 31        Acer                 Predator 17   16     ssd      256         17.3
# 96   Alienware          AW13R3-7000SLV-PUS    8     ssd      256         13.3
# 90   Alienware                 15 Notebook   16     hdd     1024         15.6
# 5        Apple      MacBook Pro (TouchBar)   16     ssd      512         15.0
#
#       price processor_brand processor_model  clock_speed graphic_card_brand  \
# 148   13872           intel      Atom Z8300         1.44              intel
# 83    17990           intel         Celeron         1.10              intel
# 108   17990             amd         A4-7210         1.80                amd
# 100   18990           intel         pentium         1.10              intel
# 73    19465             amd         A4-7210         1.80                amd
# ..      ...             ...             ...          ...                ...
# 154  178799           intel              i5         1.80              intel
# 31   178912           intel              i7         2.60             nvidia
# 96   190256           intel              i7         3.00             nvidia
# 90   199000           intel              i7         2.60             nvidia
# 5    226000           intel              i7         2.70              intel
#
#      graphic_card_size       os  weight  \
# 148                NaN  windows     1.2
# 83                 NaN  windows     2.1
# 108                NaN  windows     2.4
# 100                NaN  windows     NaN
# 73                 NaN    linux     2.4
# ..                 ...      ...     ...
# 154                NaN  windows     1.5
# 31                 NaN  windows     4.2
# 96                 6.0  windows     2.6
# 90                 8.0  windows     3.5
# 5                  2.0      mac     2.5
#
#                                               comments
# 148                                                NaN
# 83                                                 NaN
# 108                                                NaN
# 100                                                NaN
# 73                                                 NaN
# ..                                                 ...
# 154                                                NaN
# 31                                 Integrated Graphics
# 96   13.3 inch FHD (1920 x 1080) IPS Anti-Glare 300...
# 90      Maximum Display Resolution : 1920 x 1080 pixel
# 5                                                  NaN
#
# [167 rows x 15 columns]

# %%
laptops_df.sort_values(by='price', ascending=False, inplace=True)

# %%
laptops_df
# Out:
#          brand                       model  ram hd_type  hd_size  screen_size  \
# 5        Apple      MacBook Pro (TouchBar)   16     ssd      512         15.0
# 90   Alienware                 15 Notebook   16     hdd     1024         15.6
# 96   Alienware          AW13R3-7000SLV-PUS    8     ssd      256         13.3
# 31        Acer                 Predator 17   16     ssd      256         17.3
# 154  Microsoft      Surface Book CR9-00013    8     ssd      128         13.5
# ..         ...                         ...  ...     ...      ...          ...
# 73        Acer             Aspire ES1-523     4     hdd     1024         15.6
# 100       Acer    A315-31-P4CRUN.GNTSI.002    4     hdd      500         15.6
# 108       Acer  Aspire ES-15 NX.GKYSI.010     4     hdd      500         15.6
# 83        Acer     A315-31CDC UN.GNTSI.001    2     ssd      500         15.6
# 148       Acer             Aspire SW3-016     2     ssd       32         10.1
#
#       price processor_brand processor_model  clock_speed graphic_card_brand  \
# 5    226000           intel              i7         2.70              intel
# 90   199000           intel              i7         2.60             nvidia
# 96   190256           intel              i7         3.00             nvidia
# 31   178912           intel              i7         2.60             nvidia
# 154  178799           intel              i5         1.80              intel
# ..      ...             ...             ...          ...                ...
# 73    19465             amd         A4-7210         1.80                amd
# 100   18990           intel         pentium         1.10              intel
# 108   17990             amd         A4-7210         1.80                amd
# 83    17990           intel         Celeron         1.10              intel
# 148   13872           intel      Atom Z8300         1.44              intel
#
#      graphic_card_size       os  weight  \
# 5                  2.0      mac     2.5
# 90                 8.0  windows     3.5
# 96                 6.0  windows     2.6
# 31                 NaN  windows     4.2
# 154                NaN  windows     1.5
# ..                 ...      ...     ...
# 73                 NaN    linux     2.4
# 100                NaN  windows     NaN
# 108                NaN  windows     2.4
# 83                 NaN  windows     2.1
# 148                NaN  windows     1.2
#
#                                               comments
# 5                                                  NaN
# 90      Maximum Display Resolution : 1920 x 1080 pixel
# 96   13.3 inch FHD (1920 x 1080) IPS Anti-Glare 300...
# 31                                 Integrated Graphics
# 154                                                NaN
# ..                                                 ...
# 73                                                 NaN
# 100                                                NaN
# 108                                                NaN
# 83                                                 NaN
# 148                                                NaN
#
# [167 rows x 15 columns]

# %%
laptops_df = pd.read_csv('laptops.csv')

# %%
laptops_df['brand']
# Out:
# 0       Dell
# 1      Apple
# 2      Apple
# 3      Apple
# 4      Apple
#        ...
# 162     Asus
# 163     Asus
# 164     Asus
# 165     Asus
# 166     Asus
# Name: brand, Length: 167, dtype: object

# %%
laptops_df['brand'].unique()
# Out:
# array(['Dell', 'Apple', 'Acer', 'HP', 'Lenovo', 'Alienware', 'Microsoft',
#        'Asus'], dtype=object)

# %%
laptops_df['brand'].value_counts()
# Out:
# HP           55
# Acer         35
# Dell         31
# Lenovo       18
# Asus          9
# Apple         7
# Alienware     6
# Microsoft     6
# Name: brand, dtype: int64

# %% [markdown]
# #### 여행지 선정하기

# %%
import pandas as pd

city_df = pd.read_csv('world_cities.csv')

# %%
city_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           249 non-null    int64
#  1   City / Urban area    249 non-null    object
#  2   Country              249 non-null    object
#  3   Population           249 non-null    int64
#  4   Land area (in sqKm)  249 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 9.9+ KB

# %%
city_df
# Out:
#      Unnamed: 0 City / Urban area     Country  Population  Land area (in sqKm)
# 0             0      Buenos Aires   Argentina    11200000                 2266
# 1             1         Melbourne   Australia     3162000                 2080
# 2             2            Sydney   Australia     3502000                 1687
# 3             3          Brisbane   Australia     1508000                 1603
# 4             4             Perth   Australia     1177000                  964
# ..          ...               ...         ...         ...                  ...
# 244         245            Canton         USA      267000                  372
# 245         246           Spokane         USA      335000                  371
# 246         247          Tashkent  Uzbekistan     2200000                  531
# 247         248  Ho Chi Minh City     Vietnam     4900000                  518
# 248         249            Harare    Zimbabwe     1750000                  712
#
# [249 rows x 5 columns]

# %%
city_df['City / Urban area'].value_counts()
# Out:
# Harare                      1
# Riverside/San Bernardino    1
# Beijing                     1
# Huntsville                  1
# Tucson                      1
#                            ..
# Adelaide                    1
# Moscow                      1
# Nashville                   1
# Harrisburg                  1
# Lancaster                   1
# Name: City / Urban area, Length: 249, dtype: int64

# %%
city_df['Country'].value_counts()
# Out:
# USA         105
# France       15
# Brazil       10
# Canada        9
# Germany       8
#            ...
# Hungary       1
# Saudi         1
# Lebanon       1
# Vietnam       1
# Zimbabwe      1
# Name: Country, Length: 61, dtype: int64

# %%
new_df = city_df['Population'] / city_df['Land area (in sqKm)']

# %%
new_df
# Out:
# 0      4942.630185
# 1      1520.192308
# 2      2075.874333
# 3       940.736120
# 4      1220.954357
#           ...
# 244     717.741935
# 245     902.964960
# 246    4143.126177
# 247    9459.459459
# 248    2457.865169
# Length: 249, dtype: float64

# %%
new_df_2 = (new_df > 10000)

# %%
new_df_2.value_counts()
# Out:
# False    230
# True      19
# dtype: int64

# %%
new_ranks = new_df.sort_values(ascending=False)

# %%
new_ranks
# Out:
# 75     29648.760331
# 74     23917.137476
# 101    18918.918919
# 99     18157.181572
# 34     17167.381974
#            ...
# 194      458.055925
# 223      414.179104
# 57       402.222222
# 220      344.322344
# 196      329.284750
# Length: 249, dtype: float64

# %% [markdown]
# #### 여행지 선정하기 2

# %%
import numpy as np
import pandas as pd

cities_df = pd.read_csv("world_cities.csv")

cities_df['Country']
# Out:
# 0       Argentina
# 1       Australia
# 2       Australia
# 3       Australia
# 4       Australia
#           ...
# 244           USA
# 245           USA
# 246    Uzbekistan
# 247       Vietnam
# 248      Zimbabwe
# Name: Country, Length: 249, dtype: object

# %%
countries = cities_df['Country'].value_counts()

# %%
countries[countries==4]
# Out:
# Italy    4
# Name: Country, dtype: int64

# %% [markdown]
# #### 코드잇 대학교: 수강신청 준비하기

# %% [markdown]
# 2,000명의 코드잇 대학교 학생들이 수강신청을 했습니다.
#
# 수강신청에는 다음 3개의 조건이 있습니다.
#
# 1.“information technology” 과목은 심화과목이라 1학년은 수강할 수 없습니다.
# 2.“commerce” 과목은 기초과목이고 많은 학생들이 듣는 수업이라 4학년은 수강할 수 없습니다.
# 3. 수강생이 5명이 되지 않으면 강의는 폐강되어 수강할 수 없습니다.
#
# 기존 DataFrame에 “status”라는 이름의 column을 추가하고, 학생이 수강 가능한 상태이면 “allowed”, 수강 불가능한 상태이면 “not allowed”를 넣어주세요.

# %%
import pandas as pd

df = pd.read_csv('enrolment_1.csv')

# %%
df['status'] = 'allowed' # status column 추가

# 조건 1
boolean1 = df['course name'] == 'information technology'
boolean2 = df['year'] = 1

df.loc[boolean1 & boolean2, 'status'] = 'not allowed'

# %%
# 조건 2
boolean3 = df['course name'] == 'commerce'
boolean4 = df['year'] = 4

df.loc[boolean3 & boolean4, 'status'] = 'not allowed'

# %%
# 조건 3
allowed = df['status'] == 'allowed'

course_counts = df.loc[allowed, 'course name'].value_counts()

closed_courses = list(course_counts[course_counts < 5].index)

for course in closed_courses:
    df.loc[df["course name"] == course, "status"] = 'not allowed'

# %%
df
# Out:
#            id  year           course name   status
# 0     2777729     4               science  allowed
# 1     2777730     4               science  allowed
# 2     2777765     4                  arts  allowed
# 3     2777766     4                  arts  allowed
# 4     2777785     4                   mba  allowed
# ...       ...   ...                   ...      ...
# 1995  2796805     4  computer application  allowed
# 1996  2796812     4               nursing  allowed
# 1997  2796813     4               nursing  allowed
# 1998  2796814     4               nursing  allowed
# 1999  2796815     4               nursing  allowed
#
# [2000 rows x 4 columns]

# %% [markdown]
# #### 코드잇 대학교 : 강의실 배정하기 1

# %% [markdown]
# 수강 신청이 완료되었습니다. 이제 각 과목을 수강하는 학생수에 따라 크기가 다른 강의실을 배치하려고 합니다.
#
# 강의실은 규모에 따라 “Auditorium”, “Large room”, “Medium room”, “Small room” 총 4가지 종류가 있습니다.
#
# 아래 조건에 따라 강의실 종류를 지정해 주세요.
#
# 1. 80명 이상의 학생이 수강하는 과목은 “Auditorium”에서 진행됩니다.
# 2. 40명 이상, 80명 미만의 학생이 수강하는 과목은 “Large room”에서 진행됩니다.
# 3. 15명 이상, 40명 미만의 학생이 수강하는 과목은 “Medium room”에서 진행됩니다.
# 4. 5명 이상, 15명 미만의 학생이 수강하는 과목은 “Small room”에서 진행됩니다.
# 5. 폐강 등의 이유로 status가 “not allowed”인 수강생은 room assignment 또한 “not assigned”가 되어야 합니다.

# %%
import pandas as pd

df = pd.read_csv('enrolment_2.csv')

df
# Out:
#            id  year           course name   status
# 0     2777729     1               science  allowed
# 1     2777730     2               science  allowed
# 2     2777765     1                  arts  allowed
# 3     2777766     2                  arts  allowed
# 4     2777785     1                   mba  allowed
# ...       ...   ...                   ...      ...
# 1995  2796805     3  computer application  allowed
# 1996  2796812     1               nursing  allowed
# 1997  2796813     2               nursing  allowed
# 1998  2796814     3               nursing  allowed
# 1999  2796815     4               nursing  allowed
#
# [2000 rows x 4 columns]

# %%
allowed = df['status'] == 'allowed'
course_count = df.loc[allowed, 'course name'].value_counts()

course_count
# Out:
# arts                                   158
# science                                124
# commerce                               101
# english                                 56
# education                               41
#                                       ...
# mca                                      5
# building construction and mangement      5
# dental                                   5
# music                                    5
# nanotechnology                           5
# Name: course name, Length: 82, dtype: int64

# %%
auditorium = list(course_count[course_count >= 80].index)
large = list(course_count[(course_count < 80) & (course_count >= 40)].index)
medium = list(course_count[(course_count < 40) & (course_count >= 15)].index)
small = list(course_count[(course_count < 15)].index)

# %%
not_allowed = df["status"] == "not allowed"
df.loc[not_allowed, "room assignment"] = "not assigned"

for course in auditorium:
    df.loc[(df["course name"] == course) & allowed, "room assignment"] = "Auditorium"
    
for course in large:
    df.loc[(df["course name"] == course) & allowed, "room assignment"] = "Large room"
    
for course in medium:
    df.loc[(df["course name"] == course) & allowed, "room assignment"] = "Medium room"
    
for course in small:
    df.loc[(df["course name"] == course) & allowed, "room assignment"] = "Small room"

# %%
df
# Out:
#                     id  year course name   status room assignment
# 0            2777729.0   1.0     science  allowed      Auditorium
# 1            2777730.0   2.0     science  allowed      Auditorium
# 2            2777765.0   1.0        arts  allowed      Auditorium
# 3            2777766.0   2.0        arts  allowed      Auditorium
# 4            2777785.0   1.0         mba  allowed      Small room
# ...                ...   ...         ...      ...             ...
# 1996         2796812.0   1.0     nursing  allowed     Medium room
# 1997         2796813.0   2.0     nursing  allowed     Medium room
# 1998         2796814.0   3.0     nursing  allowed     Medium room
# 1999         2796815.0   4.0     nursing  allowed     Medium room
# not_allowed        NaN   NaN         NaN      NaN    not assigned
#
# [2001 rows x 5 columns]

# %% [markdown]
# #### 코드잇 대학교: 강의실 배정하기 2

# %% [markdown]
# 이전 과제에서 강의실 크기에 따라 “room assignment” column을 만들어 주었습니다.
#
# 이제 이 “room assignment”에 따라 강의실 이름을 붙여주려고 합니다.
#
# 아래 세 가지 조건을 만족하도록 코드를 작성하세요.
#
# 1. 같은 크기의 강의실이 필요한 과목에 대해 알파벳 순서대로 방 번호를 배정하세요. 예를 들어 Auditorium이 필요한 과목으로 “arts”, “commerce”, “science” 세 과목이 있다면, “arts”는 “Auditorium-1”, “commerce”는 “Auditorium-2”, “science”는 “Auditorium-3” 순서로 방 배정이 되어야 합니다.
# 2.“status” column이 “not allowed”인 수강생은 “room assignment” column을 그대로 “not assigned”로 남겨둡니다.
# 3.“room assignment” column의 이름을 “room number”로 바꿔주세요.

# %%
import pandas as pd

df = pd.read_csv('enrolment_3.csv')

# 과목별 인원 가져오기
allowed = df["status"] == "allowed"
course_counts = df.loc[allowed, "course name"].value_counts()

# %%
# 각 강의실 규모에 해당되는 과목 리스트 만들기
auditorium_list = list(course_counts[course_counts >= 80].index)
large_room_list = list(course_counts[(80 > course_counts) & (course_counts >= 40)].index)
medium_room_list = list(course_counts[(40 > course_counts) & (course_counts >= 15)].index)
small_room_list = list(course_counts[(15 > course_counts) & (course_counts > 4)].index)

# %%
# 강의실 이름 붙이기
for i in range(len(auditorium_list)):
    df.loc[(df["course name"] == sorted(auditorium_list)[i]) & allowed, "room assignment"] = "Auditorium-" + str(i + 1)

for i in range(len(large_room_list)):
    df.loc[(df["course name"] == sorted(large_room_list)[i]) & allowed, "room assignment"] = "Large-" + str(i + 1)
    
for i in range(len(medium_room_list)):
    df.loc[(df["course name"] == sorted(medium_room_list)[i]) & allowed, "room assignment"] = "Medium-" + str(i + 1)
    
for i in range(len(small_room_list)):
    df.loc[(df["course name"] == sorted(small_room_list)[i]) & allowed, "room assignment"] = "Small-" + str(i + 1)

# %%
# column 이름 바꾸기
df.rename(columns={"room assignment": "room number"}, inplace = True)

# %%
df
# Out:
#            id  year           course name   status   room number
# 0     2777729     1               science  allowed  Auditorium-3
# 1     2777730     2               science  allowed  Auditorium-3
# 2     2777765     1                  arts  allowed  Auditorium-1
# 3     2777766     2                  arts  allowed  Auditorium-1
# 4     2777785     1                   mba  allowed      Small-34
# ...       ...   ...                   ...      ...           ...
# 1995  2796805     3  computer application  allowed      Medium-7
# 1996  2796812     1               nursing  allowed     Medium-22
# 1997  2796813     2               nursing  allowed     Medium-22
# 1998  2796814     3               nursing  allowed     Medium-22
# 1999  2796815     4               nursing  allowed     Medium-22
#
# [2000 rows x 5 columns]
